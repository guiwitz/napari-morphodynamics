# %%
from IPython.display import Image

# %% [markdown]
# # Installation
#
# To use this plugin you need to be familiar with napari. Napari is an interactive viewer for images in Python, but is also becoming a popular standalone application for bioimage analysis.
#
# After downloading the napari viewer, you can download many different plugins, which are mostly specific for an image analysis task. **napari-morphodynamics** is a plugin for napari. Therefore, to get started you need a running napari installation.
#
# For more information on what is napari and how to download it, you can browse the official [napari website](https://napari.org/stable/index.html).
#
# ## Mamba environment
#
# Here we will describe one of the most common methods you could use, by using the package and environment manager [mamba](https://github.com/conda-forge/miniforge#miniforge3).<br>
# Download and execute the Miniforge3 installation file that corresponds to your system. When asked, make sure to tick the selection box that adds miniforge3 to your PATH, this will allow you to use mamba in the terminal provided by your system.

# %%
Image("images/miniforge_to_path.png")

# %% [markdown]
# ```{warning}
# Instead of mamba you could use a previously installed [conda](https://docs.conda.io/en/latest/index.html) environment manager (e.g. after installing anaconda or miniconda), this works in the exact same way, but you will need to substitute the command "mamba" in the following example with the command "conda". In addition, if you use conda, in Windows you will need to search for the "Anaconda Prompt" application, which will open a command prompt. For macOS and Linux users you can simply open a new terminal.
# ```

# %% [markdown]
# If the miniforge installation run smoothly you should be able to open a command prompt (Windows) or a terminal (macOS,Linux) on your computer and start using mamba.

# %%
Image('images/CommandPrompt.png')

# %% [markdown]
# As default, when you open a new terminal you will be using the "base" **environment**, this is the case when nothing is specified in round brackets.<br>
# What follows is the path of the directory that you are working in. For example, all the outputs of specific operations will be saved in this directory (in the example "C:\Users\anast").
#
# Now you have to make sure that you have all the packages you need to run your software in a given environment. With mamba you can have different environments on your computer, so that you can install different versions of a specific package, or even different python versions.
#
# **NEVER USE YOUR BASE ENVIRONMENT!!!**
#
# For every new project you should create a new environment. And this is what we will do for napari. We will create a new environment with the python version that we want, and the packages that we need to use for napari-morphodynamics.
#
# ### 1.Create a new mamba environment

# %% [markdown]
# You can name your environment as you wish. In this example we will call it **"test-morphodynamics"**.
#
# Type in the terminal the following code:

# %% [markdown]
# mamba create -y -n test-morphodynamics -c conda-forge python=3.10

# %% [markdown]
# As you see in this exemplar code, we will install the specific version 3.10 of python, and we will install it from the platform called conda-forge.
#
# If the code runs correctly you will be able to enter in the newly created environment as follow:

# %%
mamba activate test-morphodynamics
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
Image("images/new_env.png")

# %% [markdown]
# Now you see that you have entered the new environment that you have created, and this is specified in the **round brackets**. All the additional packages that you will need to run napari and napari-morphodynamics will need to be installed here. So make always sure that you have activated the correct environment. If nothing is specified in brackets it means that you are in the base environment.

# %% [markdown]
# ### 2. Install napari

# %% [markdown]
# After activating the correct environment, you need to install napari in it:

# %%
mamba install -c conda-forge napari pyqt

# %% [markdown]
# If napari is installed successfully in your new environment, you should be able to open the napari viewer by typing:

# %%
napari

# %%
Image('images/open_napari.png')

# %% [markdown]
# This is the procedure that you will need to follow every time you want to open napari from a mamba environment:
# - open the Command prompt (Windows)/terminal (macOS/Linus)
# - activate the environment where you have installed napari
# - type napari as command

# %% [markdown]
# ### 3.Install napari-morphodynamics

# %% [markdown]
# Now that napari is installed in the new environment you should be able to install napari-morphodyncamis. For now the only supported method is to install the development version direclty from the github repository.<br>
# To do so activate the environment that you have created for your napari-morphodynamics project and that already contains napari and install napari-morphodynaimcs via pip:

# %%
pip install git+https://github.com/guiwitz/napari-morphodynamics.git

# %% [markdown]
# To be sure that the newly installed plugin works correctly you should deactivate the environment using "mamba deactivate" and then activate it again as described above. Or if the procedure sounds to tedious, just close the command prompt and open a new one. Then activate the environment where you have installed napari-morphodynamics and type napari.
